# %% [markdown]
# <a href="https://colab.research.google.com/github/ahmedgomaa512/Technical-Discussion/blob/main/Technical_docs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Ingest

# %%
def hello ():
  return "Hi"

# %% [markdown]
# ## Modelling

# %%
x = 5

# %%
x
# Out:
# 5

# %%
y = 88
